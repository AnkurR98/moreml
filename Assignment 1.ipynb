# %% [markdown]
# <h2>Cluster an image with different Clustering Algorithms, provided I even find that image :P</h2>
# <p>PS. It do be like that sometimes</p>

# %%
import tensorflow as tf
leaves = ['D:/Leaf Dataset workspace/sampleimage.jpg', 'D:/Leaf Dataset workspace/sampleimage1.jpg']

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

with tf.device("/device:GPU:0"):
    img = plt.imread(leaves[1])
    plt.figure(figsize=(12,7))
    plt.imshow(img)
    Z = img.reshape((-1,3))

    Z = np.float32(Z)

    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
    K = 7
    ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

    center = np.uint8(center)
    res = center[label.flatten()]
    res2 = res.reshape((img.shape))

    plt.figure(figsize=(12,7))
    plt.imshow(res2)
