# %%
import csv
import os

# %%
fhand = open('D:/Leaf Dataset workspace/plantdisease/PlantVillage/PepperBell.csv','w')

# %%
disease_list = os.listdir('D:/Leaf Dataset workspace/plantdisease/PlantVillage/Pepper__bell___Bacterial_spot')

# %%
k = 0
fhand.write('Link to image'+','+'Diseased\n')
for element in disease_list:
    fhand.write('D:/Leaf Dataset workspace/plantdisease/PlantVillage/Pepper__bell___Bacterial_spot/'+element+','+'1\n')
    
fhand.close()

# %%
import pandas as pd

# %%
disease = pd.read_csv('D:\Leaf Dataset workspace\plantdisease\PlantVillage\PepperBell.csv')
disease
# Out:
#                                           Link to image  Diseased
# 0     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 1     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 2     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 3     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 4     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 5     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 6     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 7     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 8     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 9     D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 10    D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 11    D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# 12    D:/Leaf Dataset workspace/plantdisease/PlantVi...         1
# ...

# %%
fhand = open('D:/Leaf Dataset workspace/plantdisease/PlantVillage/PepperBell.csv','a')

# %%
healthy_list = os.listdir('D:/Leaf Dataset workspace/plantdisease/PlantVillage/Pepper__bell___healthy')

# %%
for element in healthy_list:
    fhand.write('D:/Leaf Dataset workspace/plantdisease/PlantVillage/Pepper__bell___healthy/'+element+','+'0\n')
    
fhand.close()

# %%
everything =  pd.read_csv('D:\Leaf Dataset workspace\plantdisease\PlantVillage\PepperBell.csv')

# %%
everything['Link to image'][998]
# Out:
# 'D:/Leaf Dataset workspace/plantdisease/PlantVillage/Pepper__bell___healthy/00208a93-7687-4e8c-b79e-3138687e0f38___JR_HL 7955.JPG'
